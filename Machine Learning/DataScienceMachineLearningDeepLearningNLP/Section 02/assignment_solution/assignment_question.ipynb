# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
inpt = input("Enter the input: ")
print(inpt)
# Out:
# My name is Singhoda

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
inpt = int(input("Enter the Number: "))
if inpt==0:
    print("The No. is Zero.")
elif inpt<0:
    print("The No. is Negative.")
else:
    print("The No. is Positive.")
# Out:
# The No. is Zero.

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a = int(input("Enter the 1st no. : "))
b = int(input("Enter the 2nd no. : "))
c = int(input("Enter the 3rd no. : "))

if(a>b):
    if(a>c):
        print("The largest no. is : ",a)
    else:
        print("The largest no. is : ",c)
elif(b>a):
    if(b>c):
        print("The largest no. is : ",b)
    else:
        print("The largest no. is : ",c)
# Out:
# The largest no. is :  125

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def fact(n):
    if n == 0:
        return 1
    else: 
        return n * fact(n-1)

num = int(input("Enter the number: "))
print(f"Factorial of the {num} is: {fact(num)}")
# Out:
# Factorial of the 6 is: 720

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a = 10
b = 23.45
c = "Anil"
d = True

print(a ,type(a))
print(b ,type(b))
print(c ,type(c))
print(d ,type(d))
# Out:
# 10 <class 'int'>
# 23.45 <class 'float'>
# Anil <class 'str'>
# False <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=int(input("Enter the 1st no.: "))
b=int(input("Enter the 2nd no.: "))

a, b = b, a
print(f"after swap a={a} & b={b}")
# Out:
# after swap a=8 & b=4

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cel = float(input("Enter the temperature in celsius: "))
fah = (cel * 9/5) + 32
print(f"The temperature in fahrenheit is {fah} degrees")
# Out:
# The temperature in fahrenheit is 97.772 degrees

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a = "Radhe"
b = "Shyam"
c = a+b
print(c)
# Out:
# RadheShyam

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = 98.25
if isinstance(a, float):
 print("a is float")
else:
 print("a is not float")
# Out:
# a is float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
def cal():
    a = int(input("Enter the first no.: "))
    b = int(input("Enter the second no.: "))

    ch = int(input("(1. Add, 2. Sub, 3. Mul, 4. Div) \n Enter your Choice: "))
    if ch == 1:
        print("Addition of two numbers is: ", a + b)
    elif ch == 2:
        print("Subtraction of two numbers is: ", a - b)
    elif ch == 3:
        print("Multiplication of two numbers is: ", a * b)
    elif ch == 4:
        print("Devision of two numbers is: ", a / b)

cal()
# Out:
# Subtraction of two numbers is:  -4

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
ch = int(input("inter the number: "))
if ch == 0:
    print("Your No. is Zero")
elif ch < 0:
    print("Your No. is Negative")
elif ch > 0:
    print("Your no. is Positive")
# Out:
# Your no. is Positive

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = float(input("Enter the no.: "))
numsq = num ** 2
print(f"Square of the {num} is: ", numsq)
# Out:
# Square of the 66.3 is:  4395.69

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
no = int(input("Enter the no."))
if no%2 == 0:
    print(f"{no} is an Even Number")
else: 
    print(f"{no} is an Odd Number")
# Out:
# 4 is an Even Number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
no = int(input("Enter your no.: "))
sum = (no * (no+1)) // 2
print(sum)
# Out:
# 4950

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
yr = int(input("Enter the year: "))
if (yr % 4 == 0 and yr % 100 != 0) or (yr % 400 == 0):
    print("Leap year")
else: 
    print("Not a leap year")
# Out:
# Not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = input("Enter the String: ")
rstring = string[::-1]
print("Reversed String: ", rstring)
# Out:
# Reversed String:  anawkammo

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = input("Enter the String: ")
if str == str[::-1]:
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# The string is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
no = [int(x) for x in input("Enter the no.s seperated by space: ").split()]
no.sort()
print(f"Soter no.s: {no}")
# Out:
# Soter no.s: [1, 15, 33, 42, 45, 65, 87, 95, 420]
