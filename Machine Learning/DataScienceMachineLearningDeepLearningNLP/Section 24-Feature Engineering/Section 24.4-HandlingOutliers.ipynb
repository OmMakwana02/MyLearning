# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lst = [2,45,32,44,66, 69,12,34,4,56,76,87, 90] 
minimum, Q1, median, Q3, maximum = np.quantile(lst, [0,0.25,0.50,0.75, 1.0])

# %%
print(minimum, Q1, median, Q3, maximum)
# Out:
# 2.0 32.0 45.0 69.0 90.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 37.0

# %%
lower_fence = Q1 - 1.5 * (IQR)
print("Lower Fence:",lower_fence)
upper_fence = Q3 + 1.5 * (IQR)
print("Upper Fence:",upper_fence)
# Out:
# Lower Fence: -23.5
# Upper Fence: 124.5

# %%
sns.boxplot(lst)
# Out:
# <Axes: >

# %%
lst = [22,45,32,44,66,29,12,34,4,56,76,-10,-100,87,90,350,250,1]

# %%
sns.boxplot(lst)
# Out:
# <Axes: >
