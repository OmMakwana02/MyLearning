# %% [markdown]
# # OOPS Concepts with Classes and Objects

# %% [markdown]
# ## 11.1 Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarious using classes and objects. This lesson covers the basic of creating classes and objects, includng indtance variables and methods.

# %%
# A class is a blue print for creating objects. Attributes, methods

class Car:
    pass

audi = Car()
bmw = Car()
# Here audi and bmw are objects, bcoz we have instantiated form the above "Car class"

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Here it will show you that audi and bmw are the objects of the car class.

# %%
# Instance Variable and Methods
# Initailalization with a constructor.
class Dog:
    # Constructor
    def __init__(self, name, age, gender): # Self keyword is responsible for accessing the variables in a class
        self.name = name
        self.age = age
        self.gender = gender
        # All the above variables are instace variables in class Dog.

# Creating Objects.
dog1 = Dog("Bruno", 3, "male")
dog2 = Dog("Lucy", 9, "female")
print(f"Dog's Info: Name-{dog1.name}, Age-{dog1.age}, Gender-{dog1.gender}")
# Out:
# Dog's Info: Name-Bruno, Age-3, Gender-male

# %% [markdown]
# Note: We can create only those instance variable which are present in the constructor, if we want to create more instance variables, we go to the construtor and we will make one using, "self.variable_name" and assigning parameter to it.

# %%
# Defining a class with instance methods.
class Gadis:
    def __init__(self,model,speed):
        self.model = model
        self.speed = speed
    
    def info(self):
        print(f"Speed of car {self.model} is {self.speed} kmph")

car1=Gadis("audi56xro", 240)
car1.info()

car2=Gadis("BMW4890", 389)
car2.info()
# Out:
# Speed of car audi56xro is 240 kmph
# Speed of car BMW4890 is 389 kmph

# %%
# Eg. Modeling a Bank Account
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposite(self,amount):
        self.balance += amount
        print(f"{amount} is been deposited to the account. \n New Blalance = {self.balance}.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance")
        else:
            self.balance = self.balance - amount
            print(f"{amount} is withdrawn. Reamining Balance = {self.balance}")

    def get_balance(self):
        return self.balance


account = BankAccount("Om", 50000)
print(account.balance)
# Out:
# 50000

# %%
account.deposite(5000)
# Out:
# 5000 is been deposited to the account.
#  New Blalance = 55000.

# %%
account.withdraw(2000)
# Out:
# 2000 is withdrawn. Reamining Balance = 53000

# %%
print(account.balance)
account.withdraw(55000)
# Out:
# 53000
# Insufficient balance

# %% [markdown]
# ## Conclusion
# Object-Oriented Programming (OOP) allows you to model real world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations, Understanding these concepts is fundamental to writing effective and maintainable Python code.

# %% [markdown]
# ## 11.2 Inheritance in Python
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows a class to inherit attributes and methods from another class. These notes covers single inheritance and multiple inheritance, demonstrating how to create and use them in Python.

# %% [markdown]
# ### Single Inheritance

# %%
# Inheritance 

# Parent Class
class Car:
    def __init__(self, windows, doors, engine):
        self.windows = windows
        self.doors = doors
        self.engine = engine

    def drive(self):
        print(f"The Person will drive the {self.engine} car.")

# %%
car1 = Car(4, 5, "petrol")
car1.drive()
# Out:
# The Person will drive the petrol car.

# %%
# class child_class(parent_class)

class Tesla(Car):
    def __init__(self, windows, doors, engine, is_selfdriving):
        super().__init__(windows, doors, engine) 
        # super() basically means that I'm just trying to call the parent class, then from parent class I'm just calling my __init__ method. 
        self.is_selfdriving = is_selfdriving
    def selfdriving(self):
        print(f"Tesla Supports self driving: {self.is_selfdriving}")

# %%
tesla1 = Tesla(5, 4, "electric", True)
tesla1.selfdriving()
# Out:
# Tesla Supports self driving: True

# %%
tesla1.drive()
# Out:
# The Person will drive the electric car.

# %% [markdown]
# ### Multiple Inheritance
# When a class inherits from more than one base class.

# %%
# Base Class 1
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        print("Subclass must implement the speak method.")
        
# Base Class 2
class Pet:
    def __init__(self, owner):
        self.owner = owner

# Derived Class - Inheriting from both the classes.
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)

    def speak(self):
        return f"{self.name} says wooff"
    
# Create an Object
dog = Dog("Stella", "Jay")
print(dog.speak())
print(f"owner = {dog.owner}")
# Out:
# Stella says wooff
# owner = Jay

# %% [markdown]
# ## 11.3 Polymorphism
# Polymorphism is a core concept in Object-Orented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. It Provides a way to perform a single action in different forms. Polymorphism is typically achieved through mehod overriding and interfaces.

# %% [markdown]
# ### -->Method Overriding
# Method Overriding allows a child class to provide a specific implementation od a method that is already defined in its parent class.

# %%
# Base Class
class Animal:
    def speak(self):
        return("Sound of the Animal")
    
# Derived Class 1
class Dog(Animal):
    def speak(self): 
        return "Woof!"
    

# Method overriding, child class can provide its own specific implementation/definition.

# Derived Class 2
class Cat(Animal):
    def speak(self):
        return "Meow!"
    
# Derived Class 3
class Cow(Animal):
    def speak(self):
        return "Moo!"
    
# Function that demonstrates Polymorphism
def animal_speak(animal):
    print(animal.speak())
    
dog = Dog()
cat = Cat()
cow = Cow()
print(dog.speak())
print(cat.speak())
print(cow.speak())

animal_speak(dog)
# Out:
# Woof!
# Meow!
# Moo!
# Woof!

# %%
# Polymorphism with Functions and Methods
class Shape:
    def area(self):
        return "The Area of the figure."
    
## Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
# Derived class 2
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius
    
# Function demonstrating polymorphsim

def print_area(shape):
    print(f"The area is {shape.area()}")

rectangle = Rectangle(4,5)
circle = Circle(45)

print_area(rectangle)
print_area(circle)
# Out:
# The area is 20
# The area is 6358.500000000001

# %% [markdown]
# ### --> Polymorphism with Abstract Base Classes
# Abstract Base Classes (ABC's) are used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promothing consistency across different implementatiion.

# %%
from abc import ABC, abstractmethod 
# This abstract method is a kind of decorater.

# Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    # @abstractmethod is just like an empty method.
    def start_engine(self):
        pass

# Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started."
    
# Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle Engine started"
    
# Function that demonstrates Polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())
    
# Create Objects of Car and Motorcycle
car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
start_vehicle(motorcycle)
# Out:
# Car engine started.
# Motorcycle Engine started

# %% [markdown]
# ## Conclusion
# Polymorphism is a powerful feature of OOP that allows for flexibility and integration in code design. it enbles a single function to handle objects of different classes, each with its own implementation of  method. By understanding and applying polymorphism, you can create more extensible ad maintainable object-oriented program.

# %% [markdown]
# ## 11.4 Encapsulation and Abstraction
# Encapsulation and Abstraction are two fundamentals principles of Object-Oriented Programming (OOP) that helps in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods that operate on the data within a single unit, while abstraction involves hiding complex imlementation details and exposing only the necessary features.

# %% [markdown]
# ### --> Encapsulation
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single usnit. It restricts direct access to some of the object's components, which is a means of preventing accidental interference and misuse of the data.

# %%
# We can do Encapsulation with Getter and Setter Method.
# But first we will learn the three access variables. 

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        # The above two variables are public variables.
        # This means we can call this variable even outside the class

# Eg.
person = Person("Om", 20)

print(person.name, person.age)
# Out:
# Om 20

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %% [markdown]
# We can see here there are two extra variables 'age' and 'name'. These variables are instance variables or public variables.

# %%
# Ther may be sceneiro where I want to define some of the variables such that outside the class I should not be able to provide it as an access. These can be some very important variables.

# %%
# Creating a private variable.
class Person:
    def __init__(self, name, age, gender):
        self.__name = name
        self.__age = age
        self.gender = gender
        # The first two variables are private variables.
        # This means we can access these variable only inside the class.
    def get_name(self):
        return self.__name

# Eg.
person = Person("Om", 20, "male")
print(person.get_name()) 
# We can see that we can access the private variables using the function that we have made inside the class.
# If we write the "get_name()" function outside the class we will not be able to access the name and age variable (bcoz they are private variables).
# Eg.
def get_name_again(self):
    return self.__name

print(person.gender)
# But in the next block we cannot access these variables directly outside the function.
# Out:
# Om
# male

# %%
print(person.name)
print(person.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(person.name)
#       2 print(person.age)
#
# AttributeError: 'Person' object has no attribute 'name'

# %%
# We can see that we cannot access the private variables outside the class.

# %%
print(person.get_name_again())
# This will show us error bcoz the function is created outside the class.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(person.get_name_again())
#
# AttributeError: 'Person' object has no attribute 'get_name_again'

# %%
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender',
#  'get_name']

# %% [markdown]
# We can see in the above output block, that we can see the public variable "gender", but we cannot se the variables name and age.
#
# Note: We cannot access the private variables from the derived class.

# %%
# Protected Variable
class Person:
    def __init__(self, name, age, gender):
        self._name = name
        self._age = age
        self.gender = gender
        # We use only single underscore( _ ) to make the variable protected.

class Employee(Person):
    def __init__(self, name, age, gender, employee_id):
        super().__init__(name, age, gender)
        self.employee_id = employee_id

    
employee = Employee("Om", 20, "Male", "44E568")
print(employee._name)
print(employee._age)
print(employee.gender)
print(employee.employee_id)

# Now we will try to access these Protected variables from outside the class.
print(person._name)
# Out:
# Om
# 20
# Male
# 44E568
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 22
#      19 print(employee.employee_id)
#      21 # Now we will try to access these Protected variables from outside the class.
# ---> 22 print(person._name)
#
# AttributeError: 'Person' object has no attribute '_name'

# %% [markdown]
# Protected Variable says that we cannot access the varivale outside the class but we can access the variable within a derived class, we can see this in the above block.
#
# We can see when we tried to access the variable from derived class we got the output´◡`, but when we tried to access the variable autside the class, we got an error.ಥ_ಥ

# %%
# Encapsulation with Getter and Setter
class Person:
    def __init__(self, name, age):
        self.__name = name # Private access modifier or variable.
        self.__age = age # Private access modifier or variable.

    # Now in order to access this prticular variable inside the class, we can definitly use it using getter mehtod.
    
    # Getter Method for name.
    def get_name(self):
        return self.__name
    # This is my getter method for name. The internal things are probable hidden over here, only the things that matter to us are available to us or visible to us.

    # Setter Method for name.
    def set_name(self, name):
        self.__name = name
    # Setter method hepls us to change any value that we give to our variable.

    # So with getter we are retriving the name/value, in setter we change the name/value itself.

    # Getter and Setter for age.
    def get_age(self):
        return self.__age
    
    def set_age(self, age):
        if age>0:
            self.__age = age
        else:
            print("Age cannot be Negative")


person = Person("Om", 20)

print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_name("Omi")
print(person.get_name())

person.set_age(-20)
# Out:
# Om
# 20
# 35
# Omi
# Age cannot be Negative

# %% [markdown]
# ### --> Abstraction
# Abstraction is the concept of hiding the complex implementation details and showing only the necessary features of an object. This helps in reducing programming complexity and effort.

# %%
from abc import ABC, abstractmethod

# Abstract Base Class
class Vehicle(ABC):
    def drive(self):
        print("The Vehicle is used to drivre.")
    # This is a normal method....

    # Abstract Method
    # This is a completely empty function, and the best thing about abstract method is that it is created in such purpose that whenever a child class inherits this base class. it says that i am giving you a functionality wrt drive, and im giving you an abstract method which you can do the implimentation with your own way.
    @abstractmethod
    def start_engine(self):
        pass

# Lets make a child class
class Car(Vehicle):
# This car class can inherit the behicle class but there is one condition, you will be able to use the method 'drive', but to use the 'start_engine' method, you have to write your own definition. 
    def start_engine(self):
        print("The Engine is started.")


def operate_vehicle(vehicle):
    vehicle.start_engine()

car = Car()
operate_vehicle(car)
# Out:
# The Engine is started.

# %% [markdown]
# ## 11.5 Magic Mathods in Python.
# Magic Methods in Python, also knowns as dunder methods (Double underscore methods), are special methods that start and end with double underscore. These methods enable you to define the behaviour of objects for built-in operations, suach as arithmetic operations, comparisons, and more.

# %% [markdown]
# ### --> Magic Methods
# Magic Methods are predefined methods in Python that you can override to change the behavior of objects. Some common magic methods include:

# %%
'''
__init__   : Initializes a new instance of a class.
__str__    : Returns a string representation of an object.
__repr__   : Returns an official string representation of an object.
__len__    : Returns the length of an object.
__getitem__: Gets an item from a container.
__setitem__: Sets an iitem in a container.
'''
# Out:
# ''

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person("Om", 20)
print(person)

# %%
# Lets Override the above function
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old."
    
    def __repr__(self):
        return f"person(name={self.name}, age={self.age})"

person = Person("Om", 20)
print(person)
print(repr(person))
# Out:
# Om is 20 years old.
# person(name=Om, age=20)

# %% [markdown]
# ## 11.6 Operator Overloading

# %%
'''
__add__     : Adds two objects using the '+' operator.
__Sub__     : Subtracts two objects using the '-' operator.
__mul__     : Multiplies two objects using the '*' operator.
__truediv__(self, other) : Divides two objects using the '/' operator.
__eq__(self, other) : Ckecks if two objects are equal using the '==' operator.
__lt__(self, other) : Ckecks if one object is less than another using the '<' operator.
__gt__(self, other) : Ckecks if one object is greater than another using the '>'
'''

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    
    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)
    
    def __mul__(self, other):
        return Vector(self.x * other.x, self.y * other.y)
    
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __repr__(self):
        return f"Vector({self.x}, {self.y})"
    

## Objects of the Vector class
v1 = Vector(2,3)
v2 = Vector(4,5)

print(v1 + v2)
print(v1 - v2)
print(v1 * v2)
print(v1 == v2)
# Out:
# Vector(6, 8)
# Vector(-2, -2)
# Vector(8, 15)
# False

# %% [markdown]
# ## Custom Exception Handling (Raise and Throw an Exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(input("Enter your D.O.B"))
age = 2024-year

try:
    if age <= 30 and age >= 20:
        print("The age is valid, so you can apply for the test.")
    else:
        raise dobException
except dobException:
    print("The age is not valid, so you cannot apply for the test.")
# Out:
# The age is valid, so you can apply for the test.
